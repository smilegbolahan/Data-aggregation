# %%
import pandas as pd

sales = pd.read_excel("products summary.xlsx", sheet_name="sales details")

# %%
sales
# Out:
#     SA. RAP ID   ZONE SALES RAP       DATE    MONTH   PRODUCT  BOXES   \
# 0        SR001  SOUTH     PETER 2021-01-01  January    Orange      18
# 1        SR002  SOUTH    BISOLA 2021-01-01  January  Cherries      17
# 2        SR003  SOUTH  VICTORIA 2021-01-01  January    Banana      92
# 3        SR004   EAST    DANIEL 2021-01-01  January     Apple      88
# 4        SR005   EAST    LOVETH 2021-01-01  January    Grapes      24
# ..         ...    ...       ...        ...      ...       ...     ...
# 442      SR008   WEST    GLORIA 2021-03-31    March  Cherries      12
# 443      SR009   WEST    ENIOLA 2021-03-31    March    Banana      91
# 444      SR010  NORTH    HANNEY 2021-03-31    March     Apple      56
# 445      SR011  NORTH  TEMITOPE 2021-03-31    March    Grapes      30
# 446      SR012  NORTH      WURA 2021-03-31    March   Mangoes      83
#
#      UNIT PRICE  TOTAL
# 0            25    450
# 1            78   1326
# 2            18   1656
# 3            45   3960
# ...

# %%
pd.options.display.max_rows = len(sales.index)
#to get all the rows in the dataframe

# %%
sales
# Out:
#     SA. RAP ID   ZONE SALES RAP       DATE     MONTH     PRODUCT  BOXES   \
# 0        SR001  SOUTH     PETER 2021-01-01   January      Orange      18
# 1        SR002  SOUTH    BISOLA 2021-01-01   January    Cherries      17
# 2        SR003  SOUTH  VICTORIA 2021-01-01   January      Banana      92
# 3        SR004   EAST    DANIEL 2021-01-01   January       Apple      88
# 4        SR005   EAST    LOVETH 2021-01-01   January      Grapes      24
# 5        SR006   EAST  TEMITOPE 2021-01-01   January     Mangoes       9
# 6        SR007   WEST     MOSUN 2021-01-01   January  Watermelon      10
# 7        SR008   WEST    GLORIA 2021-01-01   January      Orange      96
# 8        SR009   WEST    ENIOLA 2021-01-01   January    Cherries       7
# 9        SR010  NORTH    HANNEY 2021-01-01   January      Banana      80
# 10       SR011  NORTH  TEMITOPE 2021-01-01   January       Apple      86
# 11       SR012  NORTH      WURA 2021-01-01   January      Grapes      62
# ...

# %%
sales["TOTAL"].sum(axis=0)
# Out:
# 965032

# %%
sales["BOXES "].sum(axis=0)
# Out:
# 22501

# %%
sales.groupby(["ZONE"]).sum()
# Out:
#        BOXES   UNIT PRICE   TOTAL
# ZONE
# EAST     5899        4912  251373
# NORTH    5515        4579  245417
# SOUTH    5004        4971  206889
# WEST     6083        5238  261353

# %%
sales.loc[sales["ZONE"] == "SOUTH"]
# Out:
#     SA. RAP ID   ZONE SALES RAP       DATE     MONTH     PRODUCT  BOXES   \
# 0        SR001  SOUTH     PETER 2021-01-01   January      Orange      18
# 1        SR002  SOUTH    BISOLA 2021-01-01   January    Cherries      17
# 2        SR003  SOUTH  VICTORIA 2021-01-01   January      Banana      92
# 12       SR001  SOUTH     PETER 2021-01-02   January     Mangoes      86
# 13       SR002  SOUTH    BISOLA 2021-01-02   January  Watermelon      69
# 14       SR003  SOUTH  VICTORIA 2021-01-02   January      Orange      47
# 23       SR001  SOUTH     PETER 2021-01-03   January      Banana       8
# 24       SR002  SOUTH    BISOLA 2021-01-03   January       Apple      70
# 25       SR003  SOUTH  VICTORIA 2021-01-03   January      Grapes      17
# 35       SR001  SOUTH     PETER 2021-01-05   January      Orange      90
# 36       SR002  SOUTH    BISOLA 2021-01-05   January    Cherries      26
# 37       SR003  SOUTH  VICTORIA 2021-01-05   January      Banana      82
# ...

# %%
sales.iloc[2,3]
# Out:
# Timestamp('2021-01-01 00:00:00')

# %%
sales.loc[sales["ZONE"] == "SOUTH"].sum()
# Out:
# C:\Users\Muiz\AppData\Local\Temp\ipykernel_10164\2320594929.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.loc[sales["ZONE"] == "SOUTH"].sum()
# SA. RAP ID    SR001SR002SR003SR001SR002SR003SR001SR002SR003S...
# ZONE          SOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHS...
# SALES RAP     PETERBISOLAVICTORIAPETERBISOLAVICTORIAPETERBIS...
# MONTH         JanuaryJanuaryJanuaryJanuaryJanuaryJanuaryJanu...
# PRODUCT       OrangeCherriesBananaMangoesWatermelonOrangeBan...
# BOXES                                                      5004
# UNIT PRICE                                                 4971
# TOTAL                                                    206889
# dtype: object

# %%
sales.groupby(["ZONE"]).count()
# Out:
#        SA. RAP ID  SALES RAP  DATE  MONTH  PRODUCT  BOXES   UNIT PRICE  TOTAL
# ZONE
# EAST          114        114   114    114      114     114         114    114
# NORTH         102        102   102    102      102     102         102    102
# SOUTH         110        110   110    110      110     110         110    110
# WEST          121        121   121    121      121     121         121    121

# %%
sales.groupby(["PRODUCT"]).sum()
# Out:
#             BOXES   UNIT PRICE   TOTAL
# PRODUCT
# Apple         3236        2880  145620
# Banana        3341        1152   60138
# Cherries      2960        4992  230880
# Grapes        3041        6080  288895
# Mangoes       3357        2240  117495
# Orange        3324        1600   83100
# Watermelon    3242         756   38904

# %%
sales.groupby(["SALES RAP"]).sum()
# Out:
#            BOXES   UNIT PRICE   TOTAL
# SALES RAP
# BISOLA       1453        1491   62413
# DANIEL       1974        1631   87335
# ENIOLA       2014        1569   78613
# GLORIA       2031        1853   96831
# HANNEY       1955        1745   97876
# LOVETH       1882        1629   78226
# MOSUN        2038        1816   85909
# PETER        1902        1615   81944
# TEMITOPE     4215        3170  169751
# VICTORIA     1649        1865   62532
# WURA         1388        1316   63602

# %%
sales.loc[sales["SALES RAP"] == "BISOLA"].sum(axis=0)
# Out:
# C:\Users\Muiz\AppData\Local\Temp\ipykernel_10164\3309059751.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sales.loc[sales["SALES RAP"] == "BISOLA"].sum(axis=0)
# SA. RAP ID    SR002SR002SR002SR002SR002SR002SR002SR002SR002S...
# ZONE          SOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHSOUTHS...
# SALES RAP     BISOLABISOLABISOLABISOLABISOLABISOLABISOLABISO...
# MONTH         JanuaryJanuaryJanuaryJanuaryJanuaryJanuaryJanu...
# PRODUCT       CherriesWatermelonAppleCherriesWatermelonOrang...
# BOXES                                                      1453
# UNIT PRICE                                                 1491
# TOTAL                                                     62413
# dtype: object

# %%
sales.groupby(["MONTH"]).sum()
# Out:
#           BOXES   UNIT PRICE   TOTAL
# MONTH
# February    6351        5852  283964
# January     8576        7187  366786
# March       7574        6661  314282

# %%
apple_in_february = sales.loc[(sales["PRODUCT"] == "Apple") & (sales["MONTH"] == "February")]

# %%
apple_in_february
# Out:
#     SA. RAP ID   ZONE SALES RAP       DATE     MONTH PRODUCT  BOXES   \
# 164      SR002  SOUTH    BISOLA 2021-02-01  February   Apple      46
# 171      SR009   WEST    ENIOLA 2021-02-01  February   Apple      22
# 178      SR004   EAST    DANIEL 2021-02-02  February   Apple      98
# 185      SR011  NORTH  TEMITOPE 2021-02-02  February   Apple      66
# 192      SR007   WEST     MOSUN 2021-02-03  February   Apple      42
# 199      SR002  SOUTH    BISOLA 2021-02-05  February   Apple      13
# 206      SR009   WEST    ENIOLA 2021-02-05  February   Apple      36
# 213      SR004   EAST    DANIEL 2021-02-07  February   Apple      18
# 220      SR011  NORTH  TEMITOPE 2021-02-07  February   Apple      61
# 227      SR003  SOUTH  VICTORIA 2021-02-14  February   Apple      43
# 234      SR010  NORTH    HANNEY 2021-02-14  February   Apple      24
# 241      SR005   EAST    LOVETH 2021-02-16  February   Apple      70
# 248      SR001  SOUTH     PETER 2021-02-18  February   Apple      26
# ...

# %%
apple_in_february.iloc[0:,8].sum(axis=0)
# Out:
# 38700
